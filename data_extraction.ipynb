# %% [markdown]
# #### Semantic Analysis of Luxembourg based Companies

# %%
# Import necessary packages
import os                               # Package to list files in directory
import re                               # Package for regular expressions
import csv                              # Package to write to CSV files
import spacy                            # NLP package
from collections import Counter         # Get word frequency
from spacy import displacy              # For visual relation of tokens in a sentence
from spacy.matcher import Matcher       # For identifying tags

# %%
all_files = os.listdir("PwC Data/1/") #Get a list of all files in the current directory
len(all_files)
# Out:
# 635

# %%
# Prepare master output CSV file and write headers
with open('output.csv', 'w', newline='', encoding = 'utf-8') as output_file:
    writer = csv.writer(output_file)
    writer.writerow(["Numero_RCS", "Publication", "Date", "Company_Name", "Address", "Tags", "Employee_List"])    
output_file.close()

# Prepare corporate object CSV file for training tags
with open('corp_obj.csv', 'w', newline='', encoding = 'utf-8') as output_file_1:
    writer = csv.writer(output_file_1)
    writer.writerow(["Detailed_Corporate_Objective"])    
output_file_1.close()

# Prepare exception txt file
with open('expections.txt', 'w', newline='\n') as exception_file:
    exception_file.write("::EXCEPTION FILES LIST::")
exception_file.close()

# Read all files in directory
for each_file in all_files:
    with open("PwC Data/1/"+ each_file, encoding = 'utf-8') as file: #utf-8 encoding to support accents
        file_contents = file.read()
        #print(file_contents)
        print("Processing file:", each_file)
        extract_information(each_file)
    file.close()

# Call this function to identify the tags to train for nlp_module function
# Uncomment to reidentify tags for newer corporate objects
nlp_trainer()
# Out:
# Processing file: RESA_2019_002.10.txt
# Processing file: RESA_2019_002.123.txt
# Processing file: RESA_2019_002.223.txt
# Processing file: RESA_2019_002.232.txt
# Processing file: RESA_2019_002.24.txt
# Processing file: RESA_2019_002.250.txt
# Processing file: RESA_2019_002.278.txt
# Processing file: RESA_2019_002.281.txt
# Processing file: RESA_2019_002.298.txt
# Processing file: RESA_2019_002.308.txt
# Processing file: RESA_2019_002.338.txt
# Processing file: RESA_2019_002.367.txt
# Processing file: RESA_2019_002.368.txt
# Processing file: RESA_2019_002.384.txt
# Processing file: RESA_2019_002.41.txt
# Processing file: RESA_2019_002.431.txt
# Processing file: RESA_2019_002.434.txt
# Processing file: RESA_2019_002.474.txt
# Processing file: RESA_2019_002.489.txt
# Processing file: RESA_2019_002.491.txt
# Processing file: RESA_2019_002.492.txt
# Processing file: RESA_2019_002.50.txt
# Processing file: RESA_2019_002.507.txt
# Processing file: RESA_2019_002.511.txt
# Processing file: RESA_2019_002.579.txt
# Processing file: RESA_2019_002.580.txt
# Processing file: RESA_2019_002.584.txt
# Processing file: RESA_2019_002.585.txt
# Processing file: RESA_2019_002.588.txt
# Processing file: RESA_2019_002.600.txt
# Processing file: RESA_2019_002.604.txt
# Processing file: RESA_2019_002.607.txt
# Processing file: RESA_2019_002.647.txt
# Processing file: RESA_2019_002.713.txt
# Processing file: RESA_2019_002.719.txt
# Processing file: RESA_2019_002.72.txt
# Processing file: RESA_2019_002.726.txt
# Processing file: RESA_2019_002.75.txt
# Processing file: RESA_2019_002.801.txt
# Processing file: RESA_2019_002.809.txt
# Processing file: RESA_2019_002.813.txt
# Processing file: RESA_2019_002.816.txt
# Processing file: RESA_2019_002.82.txt
# Processing file: RESA_2019_002.93.txt
# Processing file: RESA_2019_003.105.txt
# Processing file: RESA_2019_003.110.txt
# Processing file: RESA_2019_003.145.txt
# Processing file: RESA_2019_003.170.txt
# Processing file: RESA_2019_003.194.txt
# Processing file: RESA_2019_003.21.txt
# Processing file: RESA_2019_003.214.txt
# Processing file: RESA_2019_003.217.txt
# Processing file: RESA_2019_003.220.txt
# Processing file: RESA_2019_003.234.txt
# Processing file: RESA_2019_003.238.txt
# Processing file: RESA_2019_003.248.txt
# Processing file: RESA_2019_003.259.txt
# Processing file: RESA_2019_003.274.txt
# Processing file: RESA_2019_003.304.txt
# Processing file: RESA_2019_003.308.txt
# Processing file: RESA_2019_003.316.txt
# Processing file: RESA_2019_003.351.txt
# Processing file: RESA_2019_003.368.txt
# Processing file: RESA_2019_003.382.txt
# Processing file: RESA_2019_003.383.txt
# Processing file: RESA_2019_003.388.txt
# Processing file: RESA_2019_003.389.txt
# Processing file: RESA_2019_003.396.txt
# Processing file: RESA_2019_003.400.txt
# Processing file: RESA_2019_003.430.txt
# Processing file: RESA_2019_003.434.txt
# Processing file: RESA_2019_003.49.txt
# Processing file: RESA_2019_003.510.txt
# Processing file: RESA_2019_003.514.txt
# Processing file: RESA_2019_003.54.txt
# Processing file: RESA_2019_003.563.txt
# Processing file: RESA_2019_003.57.txt
# Processing file: RESA_2019_003.575.txt
# Processing file: RESA_2019_003.594.txt
# Processing file: RESA_2019_003.60.txt
# Processing file: RESA_2019_003.613.txt
# Processing file: RESA_2019_003.640.txt
# Processing file: RESA_2019_003.641.txt
# Processing file: RESA_2019_003.642.txt
# Processing file: RESA_2019_003.654.txt
# Processing file: RESA_2019_003.79.txt
# Processing file: RESA_2019_004.101.txt
# Processing file: RESA_2019_004.105.txt
# Processing file: RESA_2019_004.126.txt
# Processing file: RESA_2019_004.15.txt
# Processing file: RESA_2019_004.156.txt
# Processing file: RESA_2019_004.163.txt
# Processing file: RESA_2019_004.164.txt
# Processing file: RESA_2019_004.19.txt
# Processing file: RESA_2019_004.291.txt
# Processing file: RESA_2019_004.299.txt
# Processing file: RESA_2019_004.300.txt
# Processing file: RESA_2019_004.303.txt
# Processing file: RESA_2019_004.316.txt
# Processing file: RESA_2019_004.34.txt
# Processing file: RESA_2019_004.363.txt
# Processing file: RESA_2019_004.365.txt
# Processing file: RESA_2019_004.366.txt
# Processing file: RESA_2019_004.367.txt
# Processing file: RESA_2019_004.376.txt
# Processing file: RESA_2019_004.41.txt
# Processing file: RESA_2019_004.42.txt
# Processing file: RESA_2019_004.458.txt
# Processing file: RESA_2019_004.495.txt
# Processing file: RESA_2019_004.53.txt
# Processing file: RESA_2019_004.551.txt
# Processing file: RESA_2019_004.555.txt
# Processing file: RESA_2019_004.58.txt
# Processing file: RESA_2019_004.624.txt
# Processing file: RESA_2019_004.628.txt
# Processing file: RESA_2019_004.631.txt
# Processing file: RESA_2019_012.117.txt
# Processing file: RESA_2019_012.119.txt
# Processing file: RESA_2019_012.152.txt
# Processing file: RESA_2019_012.203.txt
# Processing file: RESA_2019_012.204.txt
# Processing file: RESA_2019_012.205.txt
# Processing file: RESA_2019_012.207.txt
# Processing file: RESA_2019_012.261.txt
# Processing file: RESA_2019_012.400.txt
# Processing file: RESA_2019_012.417.txt
# Processing file: RESA_2019_012.421.txt
# Processing file: RESA_2019_012.429.txt
# Processing file: RESA_2019_012.483.txt
# Processing file: RESA_2019_012.484.txt
# Processing file: RESA_2019_012.486.txt
# Processing file: RESA_2019_012.545.txt
# Processing file: RESA_2019_012.599.txt
# Processing file: RESA_2019_012.611.txt
# Processing file: RESA_2019_012.694.txt
# Processing file: RESA_2019_012.708.txt
# Processing file: RESA_2019_012.725.txt
# Processing file: RESA_2019_012.741.txt
# Processing file: RESA_2019_012.747.txt
# Processing file: RESA_2019_012.762.txt
# Processing file: RESA_2019_012.764.txt
# Processing file: RESA_2019_012.783.txt
# Processing file: RESA_2019_012.787.txt
# Processing file: RESA_2019_012.794.txt
# Processing file: RESA_2019_013.138.txt
# Processing file: RESA_2019_013.189.txt
# Processing file: RESA_2019_013.226.txt
# Processing file: RESA_2019_013.227.txt
# Processing file: RESA_2019_013.228.txt
# Processing file: RESA_2019_013.229.txt
# Processing file: RESA_2019_013.231.txt
# Processing file: RESA_2019_013.270.txt
# Processing file: RESA_2019_013.272.txt
# Processing file: RESA_2019_013.372.txt
# Processing file: RESA_2019_013.375.txt
# Processing file: RESA_2019_013.383.txt
# Processing file: RESA_2019_013.385.txt
# Processing file: RESA_2019_013.387.txt
# Processing file: RESA_2019_013.410.txt
# Processing file: RESA_2019_013.571.txt
# Processing file: RESA_2019_013.583.txt
# Processing file: RESA_2019_013.621.txt
# Processing file: RESA_2019_013.633.txt
# Processing file: RESA_2019_013.671.txt
# Processing file: RESA_2019_013.674.txt
# Processing file: RESA_2019_013.678.txt
# Processing file: RESA_2019_013.723.txt
# Processing file: RESA_2019_013.741.txt
# Processing file: RESA_2019_013.748.txt
# Processing file: RESA_2019_013.756.txt
# Processing file: RESA_2019_013.773.txt
# Processing file: RESA_2019_013.785.txt
# Processing file: RESA_2019_013.787.txt
# Processing file: RESA_2019_013.79.txt
# Processing file: RESA_2019_013.792.txt
# Processing file: RESA_2019_013.809.txt
# Processing file: RESA_2019_013.819.txt
# Processing file: RESA_2019_013.821.txt
# Processing file: RESA_2019_013.837.txt
# Processing file: RESA_2019_013.838.txt
# Processing file: RESA_2019_013.842.txt
# Processing file: RESA_2019_013.862.txt
# Processing file: RESA_2019_014.11.txt
# Processing file: RESA_2019_014.12.txt
# Processing file: RESA_2019_014.13.txt
# Processing file: RESA_2019_014.133.txt
# Processing file: RESA_2019_014.136.txt
# Processing file: RESA_2019_014.14.txt
# Processing file: RESA_2019_014.146.txt
# Processing file: RESA_2019_014.148.txt
# Processing file: RESA_2019_014.149.txt
# Processing file: RESA_2019_017.162.txt
# Processing file: RESA_2019_017.166.txt
# Processing file: RESA_2019_017.170.txt
# Processing file: RESA_2019_017.235.txt
# Processing file: RESA_2019_017.240.txt
# Processing file: RESA_2019_017.285.txt
# Processing file: RESA_2019_017.303.txt
# Processing file: RESA_2019_017.307.txt
# Processing file: RESA_2019_017.311.txt
# Processing file: RESA_2019_017.315.txt
# Processing file: RESA_2019_017.320.txt
# Processing file: RESA_2019_017.321.txt
# Processing file: RESA_2019_017.322.txt
# Processing file: RESA_2019_017.324.txt
# Processing file: RESA_2019_017.325.txt
# Processing file: RESA_2019_017.326.txt
# Processing file: RESA_2019_017.331.txt
# Processing file: RESA_2019_017.360.txt
# Processing file: RESA_2019_017.378.txt
# Processing file: RESA_2019_017.4.txt
# Processing file: RESA_2019_017.419.txt
# Processing file: RESA_2019_017.421.txt
# Processing file: RESA_2019_017.5.txt
# Processing file: RESA_2019_017.527.txt
# Processing file: RESA_2019_017.539.txt
# Processing file: RESA_2019_017.541.txt
# Processing file: RESA_2019_017.542.txt
# Processing file: RESA_2019_017.553.txt
# Processing file: RESA_2019_017.6.txt
# Processing file: RESA_2019_017.7.txt
# Processing file: RESA_2019_017.8.txt
# Processing file: RESA_2019_017.9.txt
# Processing file: RESA_2019_018.11.txt
# Processing file: RESA_2019_018.12.txt
# Processing file: RESA_2019_018.13.txt
# Processing file: RESA_2019_018.16.txt
# Processing file: RESA_2019_018.160.txt
# Processing file: RESA_2019_018.162.txt
# Processing file: RESA_2019_018.167.txt
# Processing file: RESA_2019_018.172.txt
# Processing file: RESA_2019_018.191.txt
# Processing file: RESA_2019_018.334.txt
# Processing file: RESA_2019_018.337.txt
# Processing file: RESA_2019_018.338.txt
# Processing file: RESA_2019_018.339.txt
# Processing file: RESA_2019_018.340.txt
# Processing file: RESA_2019_018.341.txt
# Processing file: RESA_2019_018.342.txt
# Processing file: RESA_2019_018.344.txt
# Processing file: RESA_2019_018.347.txt
# Processing file: RESA_2019_018.384.txt
# Processing file: RESA_2019_018.385.txt
# Processing file: RESA_2019_018.4.txt
# Processing file: RESA_2019_018.487.txt
# Processing file: RESA_2019_018.489.txt
# Processing file: RESA_2019_018.493.txt
# Processing file: RESA_2019_018.496.txt
# Processing file: RESA_2019_018.497.txt
# Processing file: RESA_2019_018.498.txt
# Processing file: RESA_2019_018.5.txt
# Processing file: RESA_2019_018.51.txt
# Processing file: RESA_2019_018.6.txt
# Processing file: RESA_2019_018.7.txt
# Processing file: RESA_2019_018.8.txt
# Processing file: RESA_2019_018.9.txt
#
# ::150 most frequent English noun tokens::
#
# [('de', 1135), ('et', 782), ('la', 668), ('Company', 380), ('The', 327), ('à', 313), ('participations', 307), ('Luxembourg', 290), ('Société', 263), ('La', 244), ('form', 220), ('securities', 218), ('management', 198), ('des', 197), ('le', 180), ('les', 175), ('instruments', 169), ('companies', 165), ('pour', 156), ('acquisition', 154), ('par', 153), ('en', 149), ('\n', 148), ('que', 140), ('development', 137), ('dans', 134), ('société', 128), ('son', 127), ('subscription', 125), (' ', 122), ('purchase', 121), ('toute', 119), ('exchange', 117), ('toutes', 114), ('objet', 109), ('manner', 105), ('gestion', 102), ('purpose', 101), ('ou', 98), ('du', 98), ('opérations', 95), ('participation', 94), ('foreign', 93), ('qui', 92), ('interests', 92), ('ainsi', 92), ('control', 89), ('investment', 88), ('peut', 87), ('object', 85), ('bonds', 84), ('holding', 83), ('autres', 83), ('shares', 83), ('administration', 82), ('enterprises', 80), ('debentures', 79), ('social', 78), ('autre', 76), ('ce', 76), ('debt', 76), ('kind', 75), ('sous', 75), ('stock', 75), ('forme', 74), ('soit', 71), ('Grand', 71), ('commerciales', 70), ('tous', 70), ('portfolio', 69), ('mobilières', 69), ('réalisation', 65), ('obligations', 65), ('Duché', 65), ('acquire', 64), ('particular', 62), ('développement', 61), ('deposit', 59), ('quelque', 58), ('est', 57), ('sale', 56), ('company', 56), ('nature', 56), ('financial', 56), ('générale', 55), ('Art', 55), ('faciliter', 53), ('services', 53), ('ces', 52), ('sociétés', 52), ('pourra', 52), ('public', 51), ('transfer', 50), ('It', 50), ('creation', 49), ('private', 47), ('certificates', 47), ('entity', 47), ('generally', 46), ('rights', 46), ('loans', 44), ('tant', 44), ('Elle', 44), ('l’acquisition', 44), ('une', 43), ('titres', 43), ('développer', 41), ('transactions', 41), ('vente', 41), ('compte', 41), ('ﬁnancières', 40), ('souscription', 40), ('sans', 39), ('Article', 38), ('valeur', 38), ('tiers', 37), ('funds', 36), ('non', 36), ('façon', 35), ('détention', 35), ('way', 35), ('Le', 35), ('activité', 34), ('faire', 33), ('immobiliers', 33), ('manière', 33), ('l’administration', 32), ('d’un', 32), ('se', 32), ('prise', 31), ('location', 31), ('notamment', 31), ('dénomination', 30), ('disposal', 30), ('l’étranger', 30), ('gérants', 29), ('elle', 29), ('mise', 29), ('actions', 29), ('property', 29), ('ses', 29), ('capital', 28), ('guarantees', 28), ('sont', 28), ('ﬁnancial', 28), ('tout', 28), ('Law', 27), ('outre', 26), ('D’une', 26), ('’s', 26)]
#
# ::150 most frequent French noun tokens::
#
# [('the', 526), ('of', 512), ('and', 415), ('in', 395), ('Société', 272), ('La', 268), ('Luxembourg', 265), ('or', 256), ('participations', 254), ('société', 222), ('acquisition', 195), ('\n', 193), ('any', 193), ('  ', 186), (' ', 167), ("l'", 156), ('by', 144), ('management', 141), ('social', 126), ('instruments', 126), ('to', 126), ('administration', 125), ("d'", 122), ('subscription', 119), ('opérations', 111), ('objet', 107), ('Company', 99), ('securities', 99), ('vente', 96), ('other', 95), ('participation', 93), ('gestion', 89), ('may', 84), ('sociétés', 80), ('development', 75), ('The', 74), ('is', 74), ('acquire', 71), ('bonds', 71), ('commerciales', 70), ('réalisation', 70), ('form', 70), ('achat', 69), ('mobilières', 69), ('debentures', 69), ('control', 69), ('obligations', 68), ('particular', 64), ('immobilières', 62), ('purchase', 59), ('exchange', 59), ('développement', 59), ('Art', 59), ('titres', 58), ('valeur', 57), ('mise', 56), ('activité', 55), ('forme', 55), ('interests', 54), ('shares', 53), ('Elle', 52), ('services', 52), ('exploitation', 50), ('debt', 50), ('such', 49), ('rattachant', 48), ('générale', 47), ('companies', 47), ('kind', 47), ('activités', 47), ('manière', 46), ('Duché', 45), ('Le', 44), ('creation', 43), ('location', 42), ('ﬁnancières', 42), ('certificates', 42), ('tiers', 42), ('Article', 41), ('nature', 41), ('immobiliers', 41), ('échange', 41), ('biens', 40), ('Grand', 40), ('otherwise', 40), ('entreprises', 38), ('siège', 38), ('It', 38), ('purpose', 37), ('its', 36), ('étranger', 36), ('conseil', 35), ('gérants', 34), ('L’', 34), ('prise', 34), ('dénomination', 33), ('participate', 33), ('faciliter', 32), ('all', 32), ('whatsoever', 32), ('those', 32), ('transactions', 31), ('object', 31), ('souscription', 31), ('immeubles', 31), ('entreprise', 30), ('indirectement', 30), ('out', 30), ('actions', 30), ('compte', 30), ('détention', 29), ('capital', 28), ('\n ', 28), ('commandite', 28), ('valeurs', 28), ('holding', 28), ('produits', 28), ('commerciale', 27), ('contrôle', 27), ('>', 27), ('rapportant', 26), ('it', 26), ('investissement', 25), ("qu'", 24), ('directly', 24), ('émis', 24), ('enterprises', 24), ('way', 24), ('for', 23), ('généralement', 23), ('abroad', 23), ('which', 23), ('well', 22), ('qu’', 22), ('s', 22), ('notes', 22), ('including', 22), ('<', 22), ('gérant', 21), ('y', 21), ('propre', 21), ('article', 21), ('Statuts', 21), ('rights', 21), ('association', 21), ('développer', 20), ('pouvoirs', 20), ('Loi', 20), ('dette', 20), ('associés', 20)]
#
# ::150 most frequent German noun tokens::
#
# [('de', 591), ('and', 523), ('any', 303), ('Luxembourg', 292), ('la', 291), ('the', 290), ('et', 268), ('Société', 258), ('of', 249), ('The', 206), ('Company', 203), ('or', 202), ('La', 195), ('dans', 193), ('other', 179), ('que', 174), ('ou', 122), ('ainsi', 116), ('debentures', 111), ('as', 100), ('au', 93), ('les', 84), ('deposit', 75), ('certificates', 74), ('le', 72), ('control', 64), ('société', 64), ('Art', 58), ('Grand-Duché', 57), ('acquisition', 56), ('l’acquisition', 56), ('creation', 54), ('securities', 54), ('for', 53), (' ', 51), ('Le', 45), ('qu’à', 44), ('pour', 43), ('Article', 42), ('gestion', 42), ('aux', 36), ('objet', 36), ('L’objet', 36), ('l’exploitation', 35), ('forme', 33), ('l’administration', 32), ('foreign', 32), ('3.1', 32), ('étrangères', 31), ('ce', 30), ('companies', 29), ('Elle', 29), ('tout', 29), ('financial', 28), ('soit', 28), ('l’étranger', 28), ('à', 27), ('shares', 27), ('instruments', 27), ('d’un', 26), ('tous', 25), ('’s', 25), ('qui', 24), ('sous', 24), ('sans', 23), ('mise', 23), ('S.à', 23), ('D’une', 23), ('autre', 23), ('certiﬁcates', 23), ('par', 23), ('valeur', 22), ('services', 21), ('2.2', 21), ('sociétés', 21), ('une', 20), ('ces', 20), ('stock', 20), ('bonds', 20), ('undertakings', 20), ('Statuts', 20), ('est', 20), ("l'acquisition", 19), ('autres', 19), ('manner', 19), ('participation', 19), ('dénomination', 19), ('4.1', 18), ('notes', 18), ('sont', 18), ('toutes', 17), ('debt', 17), ('Tous', 17), ('rights', 17), ('activités', 17), ('réalisation', 17), ("d'autres", 17), ('pas', 16), ('to', 16), ('participations', 16), ('d’autres', 16), ('Loi', 15), ('beneﬁt', 15), ('\n', 14), ('l’achat', 14), ('créances', 14), ('form', 14), ('quelque', 14), ('y', 14), ('prend', 14), ('caution', 14), ('Law', 14), ('Les', 14), ('development', 13), ('social', 13), ('ne', 13), ('including', 13), ('by', 13), ('may', 13), ('financiers', 13), ('d’en', 13), ('personnes', 13), ('means', 13), ('présents', 12), ('sera', 12), ('En', 12), ('sur', 12), ('commune', 12), ('faciliter', 12), ('Real', 12), ('biens', 11), ('opérations', 11), ('use', 11), ('vente', 11), ('general', 11), ('Durée', 11), ("D'une", 11), ('hold', 11), ('manière', 11), ('Estate', 11), ('d’entreprises', 11), ('Social', 11), ('ses', 11), ('Dans', 10), ('immobiliers', 10), ("d'un", 10), ('l’émission', 10), ("l'achat", 10), ('holding', 10), ('disposal', 10)]

# %%
#############################################################################################################
#                                          EXTRACTION FUNCTION                                              #
#############################################################################################################

# This function is used to extract information such as the primary key (numero _RCS), publication number, 
# date of publication, company name, address & corporate object using regular expressions.

def extract_information(each_file):
    # Extract Numero RCS
    if re.search(r'Numéro RCS :\s+(.*)', file_contents):                                     # Check primary key
        numero_rcs = re.search(r'Numéro RCS :\s+(.*)', file_contents).group(1)               # Get Numero RCS
    else:
        exceptions(each_file)                                                                # Move files without key to exception
        return 0;                                                                            
    
    # Extract publication number
    if re.search(r'Référence de publication :\s+(.*)', file_contents):
        publication = re.search(r'Référence de publication :\s+(.*)', file_contents).group(1)# Get Publication number
    elif re.search(r'RESA\_\d\d\d\d\_\d\d\d', file_contents):
        publication = re.search(r'RESA\_\d\d\d\d\_\d\d\d', file_contents).group()
    else:
        publication = "NA"
        
    date = ""; company_name = "";                                                            # Initialize variables
    
    # Extract date, company name, & address
    if re.search('Déposé.*le ((.*\n){1,10})', file_contents):
        company_info = re.search('Déposé.*le ((.*\n){1,10})', file_contents).group(1)        # Get company information
        date = company_info[0:10]                                                            # Get date
        company_info_1 = company_info[11:].strip()
        company_name = company_info_1.split('\n')[0]                                         # Get company name
        company_address = company_info_1.split(company_name)[1]                              # Get company address
        if re.search(r'Siège social.*:((.*\n){1,3})', company_info):
            address = re.search(r'Siège social.*:((.*\n){1,3})', company_info).group(1)
            address = address.replace('\n',' ')
        elif re.search(r'\d.*|L-.*',company_address):
            address = company_address.replace('\n',' ')
            address = re.search(r'\d.*|L-.*',address).group()
        else:
            address = ""
        if re.search(r'((.*)) CON|STATUTS|GESEL|ASSEMBLEE|EX|NUM',address,re.IGNORECASE):   # Remove trailing words from address    
            address = re.search(r'((.*)) CON|STATUTS|GESEL|ASSEMBLEE|EX|NUM',address, re.IGNORECASE).group(1)
    else:
        company_info = ""
    
    # Extract corporate object
    if re.search(r'art.*\d.*object((.*\n){1,10})', file_contents, re.IGNORECASE):           
        corporate_obj = re.search(r'art.*\d.*object((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    elif re.search(r'^\d.*object((.*\n){1,10})', file_contents, re.IGNORECASE):
        corporate_obj = re.search(r'art.*\d.*object((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    elif re.search(r'art.*\d.*purpose((.*\n){1,10})', file_contents, re.IGNORECASE):
        corporate_obj = re.search(r'art.*\d.*purpose((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    elif re.search(r'^\d.*purpose((.*\n){1,10})', file_contents, re.IGNORECASE):
        corporate_obj = re.search(r'\d.*purpose((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    elif re.search(r'art.*\d.*obj((.*\n){1,10})', file_contents, re.IGNORECASE):
        corporate_obj = re.search(r'art.*\d.*obj((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    elif re.search(r'art.*\d.*Gegenstand((.*\n){1,10})', file_contents, re.IGNORECASE):
        corporate_obj = re.search(r'art.*\d.*Gegenstand((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    # some results might be inaccurate with the below regex, but it greatly improves the output matches
    # comment below regex block if required
    elif re.search(r'objet social((.*\n){1,10})', file_contents, re.IGNORECASE):     
        corporate_obj = re.search(r'objet social((.*\n){1,10})', file_contents, re.IGNORECASE).group(1)
        corporate_obj = corporate_obj.replace('\n',' ')
    else:
        corporate_obj = ""
    
    # Extract employee name 
    if re.findall(r'Monsieur\s(.+?),|Madame\s(.+?),',file_contents):
        employees_m = re.findall(r'Monsieur\s(.+?),',file_contents)
        employees_f = re.findall(r'Madame\s+(.+?),',file_contents)
        employees = employees_m + employees_f
    elif re.findall(r'Mr.\s(.+?),|Mrs.\s(.+?),',file_contents):
        employees_m = re.findall(r'Mr.\s(.+?),',file_contents)
        employees_f = re.findall(r'Mrs.\s+(.+?),',file_contents)
        employees = employees_m + employees_f
    else:
        employees = ""
    if employees != "":
        employees = list(dict.fromkeys(employees))                                          # Remove duplicates
        employees = str(employees)[1:-1]                                                    # Convert list to strings
    
    # Calls NLP module to extract tokens from corporate object & return a list of tags 
    tags = nlp_module(corporate_obj)
    if tags !=[]:
        tags = str(tags)[1:-1]
    else:
        tags = ""
    
    # Write files
    if company_name == "":                                                                  # Move file with no name to exception
        exceptions(each_file)
    else:
        with open('output.csv', 'a', newline='', encoding = 'utf-8') as output_file:        # Append to CSV file
            writer = csv.writer(output_file)
            writer.writerow([numero_rcs, publication, date, company_name, address, tags, employees])
        output_file.close()
        
        with open('corp_obj.csv', 'a', newline='', encoding = 'utf-8') as output_file_1:     # Append to CSV file
            writer = csv.writer(output_file_1)
            writer.writerow([corporate_obj])
        output_file_1.close()

# %%
#############################################################################################################
#                                               NLP FUNCTION                                                #
#############################################################################################################

# This function is used to extract key tags from the corporate onbective of companies to help identify the 
# key functionality & type of company

def nlp_module(corporate_obj):
    #nlp_en = spacy.load('en_core_web_sm')   Run this command if link to model is working
    #nlp_de = spacy.load('de_core_news_sm')  Run this command if link to model is working
    #nlp_fr = spacy.load('fr_core_news_sm')  Run this command if link to model is working
    
    nlp = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/en_core_web_sm/en_core_web_sm-2.0.0')
    #nlp_de = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/de_core_news_sm/de_core_news_sm-2.0.0')
    #nlp_fr = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/fr_core_news_sm/fr_core_news_sm-2.0.0')
    
    matcher = Matcher(nlp.vocab)
    complete_doc_en = nlp(corporate_obj)
    
    tags = []

    # Add match ID with no callback
    matcher.add("Acquisition", None, [{"LEMMA": "acquire"}],
                                     [{"LEMMA": "acquisition"}],
                                     [{"LEMMA": "l’acquisition"}])

    matcher.add("Investment", None, [{"LEMMA": "invest"}],
                                    [{"LEMMA": "investment"}],
                                    [{"LEMMA": "investissement"}])

    matcher.add("Holding", None, [{"LEMMA": "holds"}],
                                 [{"LEMMA": "holding"}])
    
    matcher.add("Development", None, [{"LEMMA": "développer"}],
                                     [{"LEMMA": "development"}],
                                     [{"LEMMA": "développement"}])
    
    matcher.add("Real Estate", None, [{"LEMMA": "immeubles"}],
                                     [{"LEMMA": "immobilières"}],
                                     [{"LEMMA": "immobiliers"}],
                                     [{"LEMMA": "property"}])

    matcher.add("Administration", None, [{"LEMMA": "administration"}],
                                        [{"LEMMA": "l’administration"}])

    matcher.add("Purchase", None, [{"LEMMA": "l'achat"}],
                                  [{"LEMMA": "achat"}],
                                  [{"LEMMA": "purchase"}])
                
    matcher.add("Subscription", None, [{"LEMMA": "souscription"}],
                                      [{"LEMMA": "subscription"}])
                            
    matcher.add("Exchange", None, [{"LEMMA": "exchange"}],
                                  [{"LEMMA": "échange"}])
                
    matcher.add("Foreign", None, [{"LEMMA": "foreign"}],
                                 [{"LEMMA": "étrangères"}],
                                 [{"LEMMA": "l’étranger"}])
 
    matcher.add("Management", None, [{"LEMMA": "gestion"}],
                                     [{"LEMMA": "management"}])
    
    matcher.add("Shares", None, [{"LEMMA": "shares"}],
                                [{"LEMMA": "actions"}])

    matcher.add("Bonds", None, [{"LEMMA": "bonds"}],
                               [{"LEMMA": "obligations"}])
    
    matcher.add("Debentures", None, [{"LEMMA": "debenture"}])
    
    matcher.add("Debt", None, [{"LEMMA": "debt"}],
                              [{"LEMMA": "dette"}],
                              [{"LEMMA": "créances"}])
    
    matcher.add("Securities", None, [{"LEMMA": "titres"}],
                                    [{"LEMMA": "securities"}])
    
    matcher.add("Commercial", None, [{"LEMMA": "commercial"}],
                                    [{"LEMMA": "commerciales"}],
                                    [{"LEMMA": "commerciale"}])
    
    matcher.add("Finance", None, [{"LEMMA": "finance"}],
                                 [{"LEMMA": "financiers"}],
                                 [{"LEMMA": "financial"}])
    
    matches = matcher(complete_doc_en)
    for match_id, start, end in matches:
        string_id = nlp.vocab.strings[match_id]  # Get string representation
        span = complete_doc_en[start:end]  # The matched span
        #print(string_id, span.text)
        tags.append(string_id)

    tags = list(dict.fromkeys(tags))
    return tags

# %%
#############################################################################################################
#                                            EXCEPTION FUNCTION                                             #
#############################################################################################################

# This function is used to write all files without a primary key or without an identifyable company name 
# into an exception text file for manual processing

def exceptions(each_file):
    with open('expections.txt', 'a', newline='\n', encoding = 'utf-8') as exception_file:     # Append to Exception file
            exception_file.write('\n')
            exception_file.write(each_file)
    exception_file.close()

# %%
#############################################################################################################
#                                       NLP TRAINER FUNCTION                                                #
#############################################################################################################

# This function is used to identify the key tags from the coporate objects data extracted from the input file
# These identified tags are used in the nlp_module function. Run this function everytime there are newer 
# corporate objects that have been added into the input file

def nlp_trainer():
    
    # Load NLP modules
    #nlp_en = spacy.load('en_core_web_sm')  Run this command if link to model is working
    #nlp_de = spacy.load('de_core_news_sm') Run this command if link to model is working
    #nlp_fr = spacy.load('fr_core_news_sm') Run this command if link to model is working
    nlp = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/en_core_web_sm/en_core_web_sm-2.0.0')
    nlp_de = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/de_core_news_sm/de_core_news_sm-2.0.0')
    nlp_fr = spacy.load('C:/Users/swaya/Anaconda3/Lib/site-packages/fr_core_news_sm/fr_core_news_sm-2.0.0')
    
    # File containing corporate objects of all companies.
    with open("corp_obj.csv", encoding = 'utf-8') as file:
        file_contents = file.read()
        #print(file_contents)
    file.close()
    
    # Uncomment to display links between tokens in a 'sample' sentence
    # displacy.serve(nlp(sample), style='dep')
    
    
    ## English model
    complete_doc_en = nlp(file_contents)
    
    # Select English noun chunks
    text_en = ""
    for token in complete_doc_en.noun_chunks:
        text_en = text_en + token.text + ' '
    text_noun_en = nlp(text_en)

    # Remove stop words and punctuation symbols
    words = [token.text for token in text_noun_en
              if not token.is_stop and not token.is_punct]

    # Get 150 most frequent nouns to identify tags (includes French & German non-nouns)
    word_freq = Counter(words)
    common_words_en = word_freq.most_common(150)
    print("\n::150 most frequent English noun tokens::\n")
    print(common_words_en)
    
    
    ## French model
    complete_doc_fr = nlp_fr(file_contents)

    #Select French noun chunks
    text_fr = ""
    for token in complete_doc_fr.noun_chunks:
        text_fr = text_fr + token.text + ' '
    text_noun_fr = nlp_fr(text_fr)

    # Remove stop words and punctuation symbols
    words = [token.text for token in text_noun_fr
              if not token.is_stop and not token.is_punct]
    
    # Get 150 most frequent nouns to identify tags (includes English & German non-nouns)
    word_freq = Counter(words)
    common_words_fr = word_freq.most_common(150)
    print("\n::150 most frequent French noun tokens::\n")
    print(common_words_fr)
    
    
    ## German model
    complete_doc_de = nlp_de(file_contents)

    #Select German noun chunks
    text_de = ""
    for token in complete_doc_de.noun_chunks:
        text_de = text_de + token.text + ' '

    text_noun_de = nlp_de(text_de)

    # Remove stop words and punctuation symbols
    words = [token.text for token in text_noun_de
              if not token.is_stop and not token.is_punct]
    
    # Get 150 most frequent nouns to identify tags (includes English & German non-nouns)
    word_freq = Counter(words)
    common_words_de = word_freq.most_common(150)    
    print("\n::150 most frequent German noun tokens::\n")
    print(common_words_de)
    
    # common_words_en, common_words_fr, & common_words_de are used to manually identify key tags 
    # from corporate_obj variable in nlp_module function and are grouped using matcher
